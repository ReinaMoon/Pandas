# %% [markdown]
# <a href="https://colab.research.google.com/github/ReinaMoon/Pandas/blob/main/Module3_Peer_Review_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Module 3 Peer Review Assignment
## 1. Use a new code cell to import functions from the pandas modules.
import pandas as pd

'''
Use a new code cell to import functions from the pandas module. (10%)

Use a new code cell to read in the ities_short.csv file as a pandas DataFrame, df. (10%)

Use a new code cell and enter code that will display information and the first five rows of df. (10%)

Use a new markdown cell to identify one aspect of df that is tidy and one aspect that is untidy. (10%)

Create a new code cell and enter code to display summary statistics for the numeric columns of data in df. (10%)

Create a new code cell and enter code to display a box plot of the Quantity column of df. Be sure to include a relevant title for the box plot. (10%)

Create a new markdown cell to describe how the descriptive statistics for the Quantity column from Requirement 5 – the min, 25%, 50%, 75%, and max values – correspond to the box plot of the Quantity column from Requirement 6. (10%)
'''
# Out:
# '\nUse a new code cell to import functions from the pandas module. (10%)\n\nUse a new code cell to read in the ities_short.csv file as a pandas DataFrame, df. (10%)\n\nUse a new code cell and enter code that will display information and the first five rows of df. (10%)\n\nUse a new markdown cell to identify one aspect of df that is tidy and one aspect that is untidy. (10%)\n\nCreate a new code cell and enter code to display summary statistics for the numeric columns of data in df. (10%)\n\nCreate a new code cell and enter code to display a box plot of the Quantity column of df. Be sure to include a relevant title for the box plot. (10%)\n\nCreate a new markdown cell to describe how the descriptive statistics for the Quantity column from Requirement 5 – the min, 25%, 50%, 75%, and max values – correspond to the box plot of the Quantity column from Requirement 6. (10%)\n'

# %% [markdown]
# # Task
# Analyze the provided CSV file "/content/_b2f83aa546604414ae18b296cb11fab9_ities_short.csv" by performing the following steps: import pandas, load the data into a DataFrame, display information and the first five rows, identify one tidy and one untidy aspect of the data in a markdown cell, display summary statistics for numeric columns, create a box plot of the 'Quantity' column with a title, and describe the correspondence between the 'Quantity' descriptive statistics and its box plot in a markdown cell.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Read the "ities_short.csv" file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Read the CSV file into a pandas DataFrame as requested.

# %%
df = pd.read_csv('/content/_b2f83aa546604414ae18b296cb11fab9_ities_short.csv')

# %% [markdown]
# **Reasoning**:
# The previous command failed because pandas was not imported. I need to import pandas first and then read the CSV file.

# %%
import pandas as pd
df = pd.read_csv('/content/_b2f83aa546604414ae18b296cb11fab9_ities_short.csv')

# %% [markdown]
# ## Explore the data
#
# ### Subtask:
# Display the information and the first five rows of the DataFrame.

# %% [markdown]
# **Reasoning**:
# Display information and the first five rows of the DataFrame.

# %%
df.info()
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         80000 non-null  int64
#  1   Time               80000 non-null  object
#  2   OperationType      80000 non-null  object
#  3   BarCode            80000 non-null  object
#  4   CashierName        80000 non-null  object
#  5   LineItem           80000 non-null  object
#  6   Department         80000 non-null  object
#  7   Category           80000 non-null  object
#  8   CardholderName     57533 non-null  object
#  9   RegisterName       80000 non-null  object
#  10  StoreNumber        80000 non-null  object
#  11  TransactionNumber  80000 non-null  object
#  12  CustomerCode       80000 non-null  object
#  13  Cost               80000 non-null  float64
#  14  Price              80000 non-null  float64
#  15  Quantity           80000 non-null  int64
# ...

# %% [markdown]
# ## Identify tidy and untidy aspects
#
# ### Subtask:
# Analyze the DataFrame structure and identify one tidy and one untidy aspect in a markdown cell.

# %% [markdown]
# **Reasoning**:
# Create a markdown cell to identify one tidy and one untidy aspect of the DataFrame based on the previous `df.info()` and `df.head()` outputs.

# %% [markdown]
# ## Summarize numeric columns
#
# ### Subtask:
# Display summary statistics for the numeric columns of the DataFrame.

# %% [markdown]
# **Reasoning**:
# Display the summary statistics for the numeric columns of the DataFrame using the .describe() method.

# %%
display(df.describe())
# Out:
#           Unnamed: 0          Cost         Price      Quantity     Modifiers  \
# count   80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean   219459.617163      0.341637     14.136813      1.182975      0.629602
# std    126346.937209      5.370029     78.868371      1.565064      2.273839
# min         3.000000   -219.700000  -5740.510000      1.000000   -449.730000
# 25%    110399.750000      0.110000      4.500000      1.000000      0.010000
# 50%    219678.000000      0.110000     11.290000      1.000000      0.010000
# 75%    328472.500000      0.110000     14.680000      1.000000      1.080000
# max    438149.000000    219.520000   7928.000000    120.000000     57.550000
#
#            Subtotal     Discounts      NetTotal           Tax      TotalDue  \
# count  80000.000000  80000.000000  80000.000000  77165.000000  77165.000000
# mean      15.617963      0.974036     14.643928      1.146594     16.110143
# ...

# %% [markdown]
# ## Visualize quantity column
#
# ### Subtask:
# Create a box plot of the 'Quantity' column with a relevant title.

# %% [markdown]
# **Reasoning**:
# Create a box plot of the 'Quantity' column and set the title.

# %%
import matplotlib.pyplot as plt

df['Quantity'].plot(kind='box', title='Box Plot of Quantity')
plt.show()

# %% [markdown]
# ## Describe box plot and statistics correspondence
#
# ### Subtask:
# In a markdown cell, explain how the descriptive statistics for 'Quantity' relate to its box plot.

# %% [markdown]
# **Reasoning**:
# Create a markdown cell to explain the relationship between the descriptive statistics of the 'Quantity' column and its box plot.

# %% [markdown]
# ## Identify tidy and untidy aspects
#
# ### Subtask:
# Analyze the DataFrame structure and identify one tidy and one untidy aspect in a markdown cell.

# %% [markdown]
# **Reasoning**:
# I need to identify one tidy and one untidy aspect of the DataFrame `df` and present this in a markdown cell. Since I cannot directly create a markdown cell using a code block, I will indicate the start and end of the markdown content within a code block, which will be interpreted as a markdown cell by the environment.

# %%
# Start Markdown
# Based on the df.info() and df.head() outputs:
#
# **Tidy Aspect:**
# One tidy aspect is that each variable appears to be in its own column. For example, 'OperationType', 'BarCode', 'CashierName', and 'Quantity' are all distinct columns, which aligns with the principle of having each variable as a column.
#
# **Untidy Aspect:**
# One untidy aspect is the 'TNumber_LItem' column. This column appears to contain multiple pieces of information (a transaction number and the line item description) within a single string, separated by " _ ". This violates the principle of having each observation in a row and each variable in a column, as one column contains two distinct variables.
# End Markdown

# %% [markdown]
# ## Describe box plot and statistics correspondence
#
# ### Subtask:
# In a markdown cell, explain how the descriptive statistics for 'Quantity' relate to its box plot.

# %% [markdown]
# **Reasoning**:
# Create a markdown cell to explain the relationship between the descriptive statistics and the box plot for the 'Quantity' column.

# %%
# Start Markdown
# The box plot of the 'Quantity' column provides a visual summary that directly corresponds to the calculated descriptive statistics.
#
# *   The **bottom whisker** of the box plot extends down to the minimum value of the 'Quantity' data.
# *   The **lower edge of the box** represents the first quartile (Q1), which is the 25th percentile.
# *   The **line within the box** marks the median, which is the 50th percentile (Q2).
# *   The ** upper edge of the box** represents the third quartile (Q3), which is the 75th percentile.
# *   The **top whisker** extends up to the maximum value within 1.5 times the interquartile range (IQR) from Q3. Any data points beyond this upper whisker are considered outliers and are displayed as individual points on the plot.
#
# In essence, the box plot is a graphical representation that summarizes the key percentiles and the spread of the data, directly reflecting the numerical values provided by the `describe()` method for the 'Quantity' column.
# End Markdown

# %% [markdown]
# Based on the `df.info()` and `df.head()` outputs:
#
# **Tidy Aspect:**
# One tidy aspect is that each variable appears to be in its own column. For example, 'OperationType', 'BarCode', 'CashierName', and 'Quantity' are all distinct columns, which aligns with the principle of having each variable as a column.
#
# **Untidy Aspect:**
# One untidy aspect is the 'TNumber_LItem' column. This column appears to contain multiple pieces of information (a transaction number and the line item description) within a single string, separated by " _ ". This violates the principle of having each observation in a row and each variable in a column, as one column contains two distinct variables.
